# %% [markdown]
# <a href="https://colab.research.google.com/github/cs145442/nlp-projects-with-tf2/blob/master/par_lay_conversations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/facebookresearch/ParlAI.git ~/ParlAI
# Out:
# Cloning into '/root/ParlAI'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 30400 (delta 38), reused 37 (delta 18), pack-reused 30318
# Receiving objects: 100% (30400/30400), 58.58 MiB | 13.29 MiB/s, done.
# Resolving deltas: 100% (21601/21601), done.

# %%
! cd ~/ParlAI; python setup.py develop
# Out:
# running develop
# running egg_info
# creating parlai.egg-info
# writing parlai.egg-info/PKG-INFO
# writing dependency_links to parlai.egg-info/dependency_links.txt
# writing entry points to parlai.egg-info/entry_points.txt
# writing requirements to parlai.egg-info/requires.txt
# writing top-level names to parlai.egg-info/top_level.txt
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.6/dist-packages/parlai.egg-link (link to .)
# Adding parlai 0.1.20200626 to easy-install.pth file
# Installing parlai script to /usr/local/bin
#
# Installed /root/ParlAI
# Processing dependencies for parlai==0.1.20200626
# Searching for websocket-server
# Reading https://pypi.org/simple/websocket-server/
# ...
# Best match: websocket-server 0.4
# Processing websocket_server-0.4.tar.gz
# Writing /tmp/easy_install-b38h22hb/websocket_server-0.4/setup.cfg
# ...

# %%
pip install https://github.com/rsennrich/subword-nmt/archive/master.zip
# Out:
# ...
#      | 399kB 576kB/s
# ...
#   Created wheel for subword-nmt: filename=subword_nmt-0.3.7-cp36-none-any.whl size=27017 sha256=7fea40830dc0062e5d83a420bdd5dd78662b3cc4b31d9041c603079015f1a0c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7_ih1s6v/wheels/f8/96/2f/67d2f7991a593e6f63468df1a71368ee07287c4006858a16e0
# Successfully built subword-nmt
# ...

# %%
pip install 'git+https://github.com/rsennrich/subword-nmt.git#egg=subword-nmt'

# %%
! python /root/ParlAI/parlai/scripts/safe_interactive.py -t blended_skill_talk -mf zoo:blender/blender_3B/model
# Out:
#                                  /@&%###%&&@@#
#                       .,*/((((##@@@&%%#%%&&@@@&%%#/*.
#              #@@&&&%%%%##(((///*****//(((###%%%&&&@@@@@&&%#%%#.
#          .%&@@@@@&&&%%%####((((////((((####%%%&&&@@@@@&&%%#%%####,
#            ./,,#(//**,,.....,,,,***////((((########%%%%%%%%###(((
#               /*(//**,,,....,,,,***////((((########%%%%%%%%###(#%*
#                (*,...      ...,,,***//////((((((///////(/*...,/#@@@(
#                **,,..         ...,,,,,,,,,,........,,*///*...*(#@@@@&&*
#                ./,,..          ...,,,,,,,,,........,,*//*,...*#/,,,,,/%#
#                 (*,..          ...,,,,,,,,,........,,*//*,..,/(      .,#(
#                 **,..          ...,,,,,,,,,.........,*//*,..,((       .,(#
#                  /*,..          ....,,,,,,,.....  ..,***,,,,(#         ..#&
#                  **,..          ....,,,,,,,....   ..,***,,,*#.         .,%@
#                  ./,...       B l e n d e r B o t ...***,,,*#          .*%@
# ...
